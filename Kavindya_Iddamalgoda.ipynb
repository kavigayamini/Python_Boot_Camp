# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv')

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0             6      148             72  ...                     0.627   50        1
# 1             1       85             66  ...                     0.351   31        0
# 2             8      183             64  ...                     0.672   32        1
# 3             1       89             66  ...                     0.167   21        0
# 4             0      137             40  ...                     2.288   33        1
# 5             5      116             74  ...                     0.201   30        0
# 6             3       78             50  ...                     0.248   26        1
# 7            10      115              0  ...                     0.134   29        0
# 8             2      197             70  ...                     0.158   53        1
# 9             8      125             96  ...                     0.232   54        1
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# Question1: What is the correlation between features in the dataset. and what two features have very strong correlation with the independent variable? Justify with reason

# %% [markdown]
# Corelation is relationship between multiple variables and attributes in the dataset. Using Correlation, we can get some insights such as:
# One or multiple attributes depend on another attribute or a cause for another attribute.
# One or multiple attributes are associated with other attributes.
# There are three types of correlations: Positive corelation, negative corelation and no corelation. According to this data set Insulin and Skin thicknes features have strong correation with the independent variable.
#
#  If Insulin fearure increases then feature outcome also increases or if insulin feature  decrease then outcome feature also decreases. Both features move in tandem and they have a linear relationship. As wel as If Skin thicknes  fearure increases then feature outcome also increases or if Skin thicknes  feature  decrease then outcome feature also decreases.

# %% [markdown]
# Question2: Which feature has more outliers. Explain with a visualization.

# %% [markdown]
# According to following graphs age and pregnancies fetures have more outliers.

# %%
sns.boxplot(x="Pregnancies",y="Age",data=df,hue="Outcome")

# %%
sns.jointplot(x='Outcome',y='Pregnancies',data=df)

# %%
sns.jointplot(x='Outcome',y='Age',data=df)

# %%
sns.jointplot(x='Outcome',y='BloodPressure',data=df)

# %%
sns.jointplot(x='Outcome',y='Glucose',data=df)

# %%
sns.jointplot(x='Outcome',y='Insulin',data=df)

# %%
sns.jointplot(x='Outcome',y='BMI',data=df)

# %%
sns.jointplot(x='Outcome',y='DiabetesPedigreeFunction',data=df)

# %%
sns.jointplot(x='Outcome',y='SkinThickness',data=df)

# %% [markdown]
# Question3: In which Age group Majority of people have diabetes? Make a visualization to validate your finding.

# %% [markdown]
# Answer: According to the following graph in between 20-30 of age group, majority of people have diabetes.

# %%
sns.jointplot(x='Age',y='DiabetesPedigreeFunction',data=df)
